# %%
class Car:
    pass

audi=Car()
bmw=Car()

print(type(audi))
# Out:
# <class '__main__.Car'>

# %%
print(audi)
print(bmw)

# %%
audi.windows = 4
print(audi.windows)
# Out:
# 4

# %%
ferrari= Car()
ferrari.doors = 2
print(ferrari.doors)
# Out:
# 2

# %%
dir(audi)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'windows']

# %%
dir(ferrari)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'doors']

# %%
#Initialize variables and methods
class Dog:
    # constructor
    def __init__(self,name,age,color):
        self.name=name
        self.age=age
        self.color=color

#Create objects
dog1=Dog('Tommy', 5, 'Brown')
dog2=Dog('Wilson', 8, 'Black')

# %%
print(dog1.name)
print(dog1.age)
# Out:
# Jenny
# 3

# %%
dog3 = ('Ezekeil', 4, 'Gray')
print(dog3)
# Out:
# ('Ezekeil', 4, 'Gray')

# %%
#Define a class with instance methods
class Dog:
    def __init__(self, name, age):
        self.name=name
        self.age=age

    def bark(self):
        print(f'{self.name} says woof')

dog1 = Dog('Jenny', 3)
dog1.bark()
dog2 = Dog('Kenny', 4)
# Out:
# Jenny says woof

# %%
dog2.bark()
# Out:
# Kenny says woof

# %%
#Modeling the bank account
class BankAccount:
    def __init__(self, account, balance=0):
        self.account=account
        self.balance=balance

    def deposit(self, amount):
        self.balance+=amount
        print(f"{amount} is deposited. New balance is {self.balance}")

    def withdraw(self, amount):
        if amount > self.balance:
            print('Insuuficient balance available')
        else:
            self.balance-=amount
            print(f"{amount} is withdrawn. Available balance is {self.balance}")
    
    def get_balance(self):
        return self.balance
    
#create an account
Kyle = BankAccount("Kyle", 5000)
print(Kyle.balance)

#Call instance method
Kyle.deposit(1000)
Kyle.withdraw(2000)
Kyle.get_balance()
# Out:
# 5000
# 1000 is deposited. New balance is 6000
# 2000 is withdrawn. Available balance is 4000
# 4000

# %%
class AmazonCard:
    def __init__(self, name, balance_amount = 300):
        self.name=name
        self.balance_amount=balance_amount

    def added(self, amount):
        self.balance_amount+=amount
        print(f'{amount} is deposited. The current balance is {self.balance_amount}')

    def withdrawn(self, amount):
        if amount> self.balance_amount:
            print('Insuffient Balance')
        else:
            self.balance_amount-=amount
            print(f'{amount} is deposited. The current balance is {self.balance_amount}')

    def get_balance(self):
        return self.balance_amount

# %%
account1 = AmazonCard('Alex')
print(account1.name)
print(account1.balance_amount)
# Out:
# Alex
# 300

# %%
account1.added(200)
# Out:
# 200 is deposited. The current balance is 500

# %%
account1.withdrawn(400)
# Out:
# 400 is deposited. The current balance is 100

# %%
class Car():
    def __init__(self, doors, windows, engine_type):
        self.doors=doors
        self.windows=windows
        self.engine_type=engine_type

    def drive(self):
        print(f'The enine typr of the car is {self.engine_type}')

# %%
class Tesla(Car):
    def __init__(self, doors, windows, engine_type, automated):
        super().__init__(doors, windows, engine_type)
        self.automated=automated

    def selfdriving(self):
        print(f'The car is automated: {self.automated}')

# %%
tesla1 = Tesla(4,6,'Automated', True)

# %%
tesla1.selfdriving()
print(tesla1.doors)
# Out:
# The car is automated: True
# 4

# %%
# Multiple Inheritence
# When a class inherites from more than one base class

class Animal:
    def __init__(self, name):
        self.name=name

    def speak(self):
        print('Subclass must implement this method')

#Base class 2
class Pet:
    def __init__(self, owner):
        self.owner=owner

#Derived class
class Dog(Animal, Pet):
    def __init__(self, name, owner):
        Animal.__init__(self,name)
        Pet.__init__(self, owner)

    def speak(self):
        return f'{self.name} says woof' 
    
    def seller(self):
        return f'{self.owner} wants to sell {self.name}'
    
# create an object
dog = Dog("Buddy", "Krish")
print(Dog.speak(dog))

print(Dog.seller(dog))
# Out:
# Buddy says woof
# Krish wants to sell Buddy

# %%
class Animal:
    def speak(self):
        return "Sound of the animal"
    
class dog(Animal):
    def speak(self):
        return "Woof!"
    
class cat(Animal):
    def speak(self):
        return "Meow!"

dog2=dog()
print(dog2.speak())

cat2=cat()
print(cat2.speak())
# Out:
# Woof!
# Meow!

# %%
class Account:
    def gender(self):
        return "Gender of the account holder"
    
class Male(Account):
    def gender(self):
        return "Gender of the account holder is Male"
    
class Female(Account):
    def gender(self):
        return "Gender of the account holder is Female"
    
John=Male()
print(John.gender())
# Out:
# Gender of the account holder is Male

# %%
# Polymorphism with Functionsand Methods
# base class
class Shape:
    def area(self):
        return "The area of the segment"
    
class Rectangle:
    def __init__(self, length, width):
        self.length=length
        self.width=width

    def area(self):
        return self.length * self.width
    
class Square:
    def __init__(self, side):
        self.side=side
    
    def area(self):
        return self.side*self.side
    
class Circle:
    def __init__(self, radius):
        self.radius=radius

    def area(self):
        return round(3.14*self.radius*self.radius,2)
    
#Function that demonstrates polymorphism

def print_area(shape):
    print(f'The area is {shape.area()}')
    
rectangle1 = Rectangle(4,5)
circle1 = Circle(3)

# %%
print_area(rectangle1)
print_area(circle1)
# Out:
# The area is 20
# The area is 28.26

# %%
# Polymorphism with abstract base classes
from abc import ABC,abstractmethod

# Define an abstract class
class Vehicle(ABC):
    @abstractmethod
    def start_engine(Vehicle):
        return "The engine has started"
    
#Derived class 1
class Car(Vehicle):
    def start_engine(self):
        return "The car has started"
    
#Derived class 2
class Motorcycle(Vehicle):
    def start_engine(self):
        return "The motorcycle has started"

#polymorphism
def start_vehicle(vehicle):
    print(vehicle.start_engine())

car = Car()
motorcycle = Motorcycle()

start_vehicle(car)
start_vehicle(motorcycle)
# Out:
# The car has started
# The motorcycle has started

# %%
#Encapsulation
class Person:
    def __init__(self,name,age):
        self.name=name #Public variable
        self.age=age #Public variable

person=Person("Krish", 34)
print(person.name)
# Out:
# Krish

# %%
dir(person)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'age',
#  'name']

# %%
class Person:
    def __init__(self,name,age,gender):
        self.__name=name #Private variable
        self.__age=age #Private variable
        self.gender=gender

person=Person("Krish", 34, "M")

def get_name(person):
    return person._Person__name

# %%
dir(person)
# Out:
# ['_Person__age',
#  '_Person__name',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'gender']

# %%
get_name(person)
# Out:
# 'Krish'

# %%
class Person:
    def __init__(self,name,age,gender):
        self._name=name #Protected variable
        self._age=age #Protected variable
        self.gender=gender

class Employee(Person):
    def __init__(self,name,age,gender):
        super().__init__(name,age,gender)

employee= Employee("Krish",34, "Male")
print(employee._name)
# Out:
# Krish

# %%
#encapsulation with getter and setter
class Person:
    def __init__(self,name,age):
        self.__name=name #Private access modifier or variable
        self.__age=age #Private variable

    #getter method for name
    def get_name(self):
        return self.__name
    
    #setter method for name
    def set_name(self,name):
        self.__name=name

    #getter method for age
    def get_age(self):
        return self.__age
    
    #setter method for age
    def set_age(self, age):
        if age>0:
            self.__age=age
        else:
            print("The age cannot be negative")

person=Person("Krish",32)

print(person.get_name())
print(person.get_age())

person.set_age(25)
print(person.get_age())

person.set_name("Krishiv")
print(person.get_name())
# Out:
# Krish
# 32
# 25
# Krishiv
