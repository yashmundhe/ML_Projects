# %%
with open('source.txt','r') as file:
    content = file.read()
    print(content)
# Out:
# Hello Guys
# Welcome To The Course

# %%
with open('source.txt','r') as file:
    lines = file.readlines()
    for line in lines:
        print(line.strip())
# Out:
# Hello Guys
# Welcome To The Course

# %%
with open('source.txt','r') as file:
    for line in file:
        print(line.strip())
# Out:
# Hello Guys
# Welcome To The Course

# %%
with open('source.txt', 'w') as file:
    file.write('Hi, How is it going?\n')
    file.write('I am doing great!')

# %%
with open('source.txt', 'a') as file:
    file.write('\nHow about you?\n')
    file.write('I am good, thanks for asking')
