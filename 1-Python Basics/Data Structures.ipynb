# %%
lis = []
print(type(lis))
# Out:
# <class 'list'>

# %%
list = [1, 2, 5, "Data",7.5]

# %%
print(list)
# Out:
# [1, 2, 5, 'Data', 7.5]

# %%
list = ["Banana", "Cherry", "Apple", "Guava", "Strawberry"]

# %%
print(list)
# Out:
# ['Banana', 'Cherry', 'Apple', 'Guava', 'Strawberry']

# %%
list[1] = "Blackberry"

# %%
print(list)
# Out:
# ['Banana', 'Blackberry', 'Apple', 'Guava', 'Strawberry']

# %%
print(list[2])
# Out:
# Apple

# %%
print(list[-2])
# Out:
# Guava

# %%
print(list[1:-1])
# Out:
# ['Blackberry', 'Apple', 'Guava']

# %%
list[3] = "Muskmelon"
print(list)
# Out:
# ['Banana', 'Blackberry', 'Apple', 'Muskmelon', 'Strawberry']

# %%
list.append("Blueberry")

# %%
list.insert(1, "Papaya")

# %%
print(list)
# Out:
# ['Banana', 'Papaya', 'Blackberry', 'Apple', 'Muskmelon', 'Strawberry', 'Blueberry']

# %%
list[1] = "Mango"

# %%
print(list)
# Out:
# ['Banana', 'Mango', 'Blackberry', 'Apple', 'Muskmelon', 'Strawberry', 'Blueberry']

# %%
list.extend(["Orange", "Pineapple"])

# %%
print(list)
# Out:
# ['Banana', 'Mango', 'Blackberry', 'Apple', 'Muskmelon', 'Strawberry', 'Blueberry', 'Orange', 'Pineapple']

# %%
popped_fruits = list.pop()
print(popped_fruits)
print(list)
# Out:
# Pineapple
# ['Banana', 'Mango', 'Blackberry', 'Apple', 'Muskmelon', 'Strawberry', 'Blueberry', 'Orange']

# %%
list.sort()
print(list)
# Out:
# ['Apple', 'Banana', 'Blackberry', 'Blueberry', 'Mango', 'Muskmelon', 'Orange', 'Strawberry']

# %%
list.reverse()

# %%
print(list)
# Out:
# ['Strawberry', 'Orange', 'Muskmelon', 'Mango', 'Blueberry', 'Blackberry', 'Banana', 'Apple']

# %%
list.clear()
print(list)
# Out:
# []

# %%
square = [num**2 for num in range(1,11,1)]
print(square)
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100]

# %%
lst = []
for i in range(10):
    if i%2 == 0:
        lst.append(i)

print(lst)
# Out:
# [0, 2, 4, 6, 8]

# %%
even_numbers = [i for i in range(10) if i%2 == 0]
print(even_numbers)
# Out:
# [0, 2, 4, 6, 8]

# %%
lst1 = [1, 2, 3, 4, 5]
lst2 = ["a", "b", "c"]

result = [(p,q) for p in lst1 for q in lst2]
print(result)
# Out:
# [(1, 'a'), (1, 'b'), (1, 'c'), (2, 'a'), (2, 'b'), (2, 'c'), (3, 'a'), (3, 'b'), (3, 'c'), (4, 'a'), (4, 'b'), (4, 'c'), (5, 'a'), (5, 'b'), (5, 'c')]

# %%
word = ["Hey", "How's", "it", "going"]
length = [len(words) for words in word]
print(length)
# Out:
# [3, 5, 2, 5]

# %%
matrix = [[1, 2], 
          [3, 4]]

transposed = list(map(list, zip(*matrix)))

print(transposed)
# Out:
# [[1, 3], [2, 4]]

# %%
matri = [[1, 2, 4],
         [3, 4, 5],
         [6, 7, 8]]
transposed = print(list(map(list, zip(*matri))))
# Out:
# [[1, 3, 6], [2, 4, 7], [4, 5, 8]]

# %%
d= 1, "Kitty", 3.5
print(d)
print(type(d))
# Out:
# (1, 'Kitty', 3.5)
# <class 'tuple'>

# %%
a, b, c =d
print(a)
# Out:
# 1

# %%
t = (1, 2, 3, 4, 5)
first, *middle, last = t
print(first)
print(middle)
print(last)
# Out:
# 1
# [2, 3, 4]
# 5

# %%
nested_tuple = ((1, 2), (3, 4, 5), (6, 7))
print(nested_tuple)
# Out:
# ((1, 2), (3, 4, 5), (6, 7))

# %%
for i in nested_tuple:
    for item in i:
        print(item, end= " ")
    print()
# Out:
# 1 2
# 3 4 5
# 6 7
